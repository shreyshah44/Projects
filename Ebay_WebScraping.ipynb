# %% [markdown]
# # Web Scraping: Which sellers advertise/sponsor 'Ipad4' on Ebay
#
# The following notebook is an end to end process of scraping product (Ipad4) information from Ebay and saving it in a MySQL table to conduct data wranglings and manipulations. It has the following steps:
#
# 1)Storing sponsored item and non-sponsored item url links for Ipad4 for the first 10 pages on Ebay as 2 separate txt files
#
# 2)For both sponsored and non-sponsored items, downloading every item page as a htm file in respective folders
#
# 3)Scraping different metrics for each item for both sponsored and non-sponsored types
#
# 4)Creating MySQL database and tables for sponsored and non-sponsored items
#
# 5)Analysing this data to identify the types of sellers who advertise/sponsor 'Ipad4' on Ebay

# %%
import requests
import json
from bs4 import BeautifulSoup as bs
from time import sleep
import os
import re
from tqdm import tqdm
import pandas as pd
import pymysql

# %% [markdown]
# ### Storing sponsored and non-sponsored item url links for the first 10 pages in sponsored.txt and non-sponsored.txt

# %%
### Define variables and lists 
pages = [str(i) for i in range(1,11)]
sponsored_links = []
nonsponsored_links=[]
link_regex = re.compile(r"(.*)\?.*")

###Run loop for 10 pages 
for page in pages:
    
    ### Get the page details in soup element
    
    url_page="https://www.ebay.com/sch/i.html?_from=R40&_nkw=ipad+4&_sacat=0&rt=nc&LH_BIN=1&_ipg=100&_pgn="+page
    response_page= requests.get(url_page,agent)
    page_soup=bs(response_page.text,"html.parser")
    page_soup
    h3 = page_soup.findAll("h3")
    for element in h3:
        
        ###identify if item is sponsored  and store item link in sponsored.txt
        
        if("s-item__title--has-tags" in str(element["class"])): # is a sponsored
            s_link = link_regex.sub(r'\1',element.parent['href'])
            sponsored_links.append(s_link)
            with open("sponsored.txt", "a") as file:
                file.write(s_link)
                file.write("\n")
                
        ###identify if item is non-sponsored and store item link in non-sponsored.txt
        
        elif("s-item__title" in str(element["class"])):
            ns_link = link_regex.sub(r'\1',element.parent['href'])
            nonsponsored_links.append(ns_link)
            with open("non_sponsored.txt", "a") as file:
                file.write(ns_link)
                file.write("\n")
    sleep(2)
    print("Page "+page+" completed.")
# Out:
# Page 1 completed.
# Page 2 completed.
# Page 3 completed.
# Page 4 completed.
# Page 5 completed.
# Page 6 completed.
# Page 7 completed.
# Page 8 completed.
# Page 9 completed.
# Page 10 completed.

# %%
###Get current working directory
current_working_directory=os.getcwd()
current_working_directory
# Out:
# 'C:\\Users\\Shrey Shah\\Documents\\GitHub\\DDR'

# %%
###Make 2 new folders as 'sponsored' and "non-sponsored"
os.mkdir("sponsored")
os.mkdir("non-sponsored")

# %%
###Declare variables for sponsored and non-sponsored working directories
directory_sponsored = current_working_directory+"/sponsored"
directory_non_sponsored = current_working_directory+"/non-sponsored"
print(directory_sponsored)
print(directory_non_sponsored)
# Out:
# C:\Users\Shrey Shah\Documents\GitHub\DDR/sponsored
# C:\Users\Shrey Shah\Documents\GitHub\DDR/non-sponsored

# %%
os.chdir(current_working_directory)

### Read all the item url links from sponsored.txt
with open("sponsored.txt","r") as file:
    all_lines = file.readlines()

# %%
### Change working directory to sponsored folder

os.chdir(directory_sponsored)
os.getcwd()
# Out:
# 'C:\\Users\\Shrey Shah\\Documents\\GitHub\\DDR\\sponsored'

# %% [markdown]
# ### For sponsored items,download every item page and store as htm file in sponsored folder

# %%
### For sponsored items,download every item page and store as htm file in sponsored folder

sponsored_items = []
for i in tqdm(range(0,len(all_lines))):
    url_item_line=all_lines[i]
    url_item_line = url_item_line.replace("\n","")
    try:
        response_item = requests.get(url_item_line,agent)
        sleep(2)
        item_regex = re.compile('.*(itm/[a-zA-Z0-9-]+/)(.*)')
        current_itemid = item_regex.sub(r'\2',url_item_line)
    except Exception:
        current_itemid = i
        print("Error occured at",i)
    sponsored_items.append(current_itemid)
    with open(current_itemid + ".htm", "w", encoding = 'utf-8') as file:
        file.write(response_item.text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 130/130 [06:00<00:00,  2.90s/it]

# %%
os.chdir(current_working_directory)

### Read all the item url links from non_sponsored.txt
with open("non_sponsored.txt","r") as file:
    all_lines = file.readlines()

# %%
### Change working directory to non-sponsored folder

os.chdir(directory_non_sponsored)
os.getcwd()
# Out:
# 'C:\\Users\\Shrey Shah\\Documents\\GitHub\\DDR\\non-sponsored'

# %% [markdown]
# ### For non-sponsored items,download every item page and store as htm file in non-sponsored folder

# %%
### For non-sponsored items,download every item page and store as htm file in non-sponsored folder

non_sponsored_items = []
for i in tqdm(range(0,len(all_lines))):
    url_item_line=all_lines[i]
    url_item_line = url_item_line.replace("\n","")
    try:
        response_item = requests.get(url_item_line,agent)
        item_regex = re.compile('.*(itm/[a-zA-Z0-9-]+/)(.*)')
        current_itemid = item_regex.sub(r'\2',url_item_line)
    except Exception as e:
        print("Error occured at",i,'\n' ,e)
        current_itemid = str(i)
    non_sponsored_items.append(current_itemid)
    with open(current_itemid + ".htm", "w", encoding = 'utf-8') as file:
        file.write(response_item.text)
        file.close()
    sleep(2)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [45:47<00:00,  2.74s/it]

# %%
### Changing working directory to sponsored folder
os.chdir(directory_sponsored)
os.getcwd()
# Out:
# 'C:\\Users\\Shrey Shah\\Documents\\GitHub\\DDR\\sponsored'

# %% [markdown]
# ### Getting Metrics for Sponsored Items

# %%
###Declaring storing variable lists for sponsored items 

soup_pages_s = []
sellernames_s=[]
sellerscores_s=[]
itemprices_s=[]
itemssold_s=[]
bestoffers_s=[]
titles_s=[]
returns_allowed_s=[]
shipping_prices_s=[]
conditions_s=[]


### Running loop for every sponsored item to get different metrics and informations
for i in range(0,len(sponsored_items)):
    with open(sponsored_items[i]+".htm",encoding ='utf-8') as file:
        soup = bs(file.read(),"html.parser")
        soup_pages_s.append(soup)
        file.close()

### Getting sellername
    sellername = soup.find("span",class_="mbg-nw").text
    sellernames_s.append(sellername)

### Getting seller score 
    sellerscore = soup.find("span",class_="mbg-l").find("a").text
    sellerscores_s.append(sellerscore)

### Getting item price    
    itemprice = soup.find("span",class_="notranslate").text
    itemprices_s.append(itemprice)

### Getting number of items sold 
    itemsold = soup.find("a",class_="vi-txt-underline")
    if (itemsold!=None):
        itemsold=itemsold.text
    else:
        itemsold=None
    itemssold_s.append(itemsold)

### Getting if item has best offer
    bestoffer = soup.find("div", class_="vi-bbox-dspn u-flL lable boLable")
    if (bestoffer!=None):
        bestoffer=bestoffer.text
    else:
        bestoffer=None
    bestoffers_s.append(bestoffer)

### Getting title for item 
    title = soup.find("h1", class_="it-ttl")
    title = title.text
    titles_s.append(title)

### Getting information if returns allowed for item
    return_allowed = soup.find("span",id="vi-ret-accrd-txt")
    if (return_allowed!=None):
        return_allowed=return_allowed.text
    else:
        return_allowed=None
    returns_allowed_s.append(return_allowed) 

### Getting shipping price for item   
    shipping_price = soup.find("span", id="shSummary").find("span").text
    shipping_prices_s.append(shipping_price)

### Getting current condition of the item
    condition = soup.find("div", id="vi-itm-cond").text
    conditions_s.append(condition)

### Check progress    
    print("Metrics for Item",i+1,"have been computed")
# Out:
# Metrics for Item 1 have been computed
# Metrics for Item 2 have been computed
# Metrics for Item 3 have been computed
# Metrics for Item 4 have been computed
# Metrics for Item 5 have been computed
# Metrics for Item 6 have been computed
# Metrics for Item 7 have been computed
# Metrics for Item 8 have been computed
# Metrics for Item 9 have been computed
# Metrics for Item 10 have been computed
# Metrics for Item 11 have been computed
# Metrics for Item 12 have been computed
# Metrics for Item 13 have been computed
# Metrics for Item 14 have been computed
# Metrics for Item 15 have been computed
# Metrics for Item 16 have been computed
# Metrics for Item 17 have been computed
# Metrics for Item 18 have been computed
# Metrics for Item 19 have been computed
# Metrics for Item 20 have been computed
# Metrics for Item 21 have been computed
# Metrics for Item 22 have been computed
# Metrics for Item 23 have been computed
# Metrics for Item 24 have been computed
# Metrics for Item 25 have been computed
# Metrics for Item 26 have been computed
# Metrics for Item 27 have been computed
# Metrics for Item 28 have been computed
# Metrics for Item 29 have been computed
# Metrics for Item 30 have been computed
# Metrics for Item 31 have been computed
# Metrics for Item 32 have been computed
# Metrics for Item 33 have been computed
# Metrics for Item 34 have been computed
# Metrics for Item 35 have been computed
# Metrics for Item 36 have been computed
# Metrics for Item 37 have been computed
# Metrics for Item 38 have been computed
# Metrics for Item 39 have been computed
# Metrics for Item 40 have been computed
# Metrics for Item 41 have been computed
# Metrics for Item 42 have been computed
# Metrics for Item 43 have been computed
# Metrics for Item 44 have been computed
# Metrics for Item 45 have been computed
# Metrics for Item 46 have been computed
# Metrics for Item 47 have been computed
# Metrics for Item 48 have been computed
# Metrics for Item 49 have been computed
# Metrics for Item 50 have been computed
# Metrics for Item 51 have been computed
# Metrics for Item 52 have been computed
# Metrics for Item 53 have been computed
# Metrics for Item 54 have been computed
# Metrics for Item 55 have been computed
# Metrics for Item 56 have been computed
# Metrics for Item 57 have been computed
# Metrics for Item 58 have been computed
# Metrics for Item 59 have been computed
# Metrics for Item 60 have been computed
# Metrics for Item 61 have been computed
# Metrics for Item 62 have been computed
# Metrics for Item 63 have been computed
# Metrics for Item 64 have been computed
# Metrics for Item 65 have been computed
# Metrics for Item 66 have been computed
# Metrics for Item 67 have been computed
# Metrics for Item 68 have been computed
# Metrics for Item 69 have been computed
# Metrics for Item 70 have been computed
# Metrics for Item 71 have been computed
# Metrics for Item 72 have been computed
# Metrics for Item 73 have been computed
# Metrics for Item 74 have been computed
# Metrics for Item 75 have been computed
# Metrics for Item 76 have been computed
# Metrics for Item 77 have been computed
# Metrics for Item 78 have been computed
# Metrics for Item 79 have been computed
# Metrics for Item 80 have been computed
# Metrics for Item 81 have been computed
# Metrics for Item 82 have been computed
# Metrics for Item 83 have been computed
# Metrics for Item 84 have been computed
# Metrics for Item 85 have been computed
# Metrics for Item 86 have been computed
# Metrics for Item 87 have been computed
# Metrics for Item 88 have been computed
# Metrics for Item 89 have been computed
# Metrics for Item 90 have been computed
# Metrics for Item 91 have been computed
# Metrics for Item 92 have been computed
# Metrics for Item 93 have been computed
# Metrics for Item 94 have been computed
# Metrics for Item 95 have been computed
# Metrics for Item 96 have been computed
# Metrics for Item 97 have been computed
# Metrics for Item 98 have been computed
# Metrics for Item 99 have been computed
# Metrics for Item 100 have been computed
# Metrics for Item 101 have been computed
# Metrics for Item 102 have been computed
# Metrics for Item 103 have been computed
# Metrics for Item 104 have been computed
# Metrics for Item 105 have been computed
# Metrics for Item 106 have been computed
# Metrics for Item 107 have been computed
# Metrics for Item 108 have been computed
# Metrics for Item 109 have been computed
# Metrics for Item 110 have been computed
# Metrics for Item 111 have been computed
# Metrics for Item 112 have been computed
# Metrics for Item 113 have been computed
# Metrics for Item 114 have been computed
# Metrics for Item 115 have been computed
# Metrics for Item 116 have been computed
# Metrics for Item 117 have been computed
# Metrics for Item 118 have been computed
# Metrics for Item 119 have been computed
# Metrics for Item 120 have been computed
# Metrics for Item 121 have been computed
# Metrics for Item 122 have been computed
# Metrics for Item 123 have been computed
# Metrics for Item 124 have been computed
# Metrics for Item 125 have been computed
# Metrics for Item 126 have been computed
# Metrics for Item 127 have been computed
# Metrics for Item 128 have been computed
# Metrics for Item 129 have been computed
# Metrics for Item 130 have been computed

# %% [markdown]
# ### Getting metrics for Non-Sponsored Items

# %%
### Change working directory to non-sponsored folder
os.chdir(directory_non_sponsored)
os.getcwd()
# Out:
# 'C:\\Users\\Shrey Shah\\Documents\\GitHub\\DDR\\non-sponsored'

# %%
### Declaring storing variable lists for sponsored items 

soup_pages_ns = []
sellernames_ns=[]
sellerscores_ns=[]
itemprices_ns=[]
itemssold_ns=[]
bestoffers_ns=[]
titles_ns=[]
returns_allowed_ns=[]
shipping_prices_ns=[]
conditions_ns=[]

### Running loop for every non-sponsored item to get different metrics and informations
for i in range(0,len(non_sponsored_items)):
    with open(non_sponsored_items[i]+".htm",encoding ='utf-8') as file:
        soup = bs(file.read(),"html.parser")
        soup_pages_ns.append(soup)
        file.close()
        
### Getting sellername
    sellername = soup.find("span",class_="mbg-nw").text
    sellernames_ns.append(sellername)

### Getting seller score
    sellerscore = soup.find("span",class_="mbg-l").find("a").text
    sellerscores_ns.append(sellerscore)

### Getting item price 
    itemprice = soup.find("span",class_="notranslate").text
    itemprices_ns.append(itemprice)

### Getting number of items sold 
    itemsold = soup.find("a",class_="vi-txt-underline")
    if (itemsold!=None):
        itemsold=itemsold.text
    else:
        itemsold=None
    itemssold_ns.append(itemsold)

### Getting if item has best offer
    bestoffer = soup.find("div", class_="vi-bbox-dspn u-flL lable boLable")
    if (bestoffer!=None):
        bestoffer=bestoffer.text
    else:
        bestoffer=None
    bestoffers_ns.append(bestoffer)

### Getting title for item
    title = soup.find("h1", class_="it-ttl")
    title = title.text
    titles_ns.append(title)

### Getting information if returns allowed for item
    return_allowed = soup.find("span",id="vi-ret-accrd-txt")
    if (return_allowed!=None):
        return_allowed=return_allowed.text
    else:
        return_allowed=None
    returns_allowed_ns.append(return_allowed) 

### Getting shipping price for item  
    shipping_price = soup.find("span", id="shSummary").find("span").text
    shipping_prices_ns.append(shipping_price)

### Getting current condition of the item
    condition = soup.find("div", id="vi-itm-cond").text
    conditions_ns.append(condition)

### Check progress     
    print("Metrics for Item",i+1,"have been computed")
# Out:
# Metrics for Item 1 have been computed
# Metrics for Item 2 have been computed
# Metrics for Item 3 have been computed
# Metrics for Item 4 have been computed
# Metrics for Item 5 have been computed
# Metrics for Item 6 have been computed
# Metrics for Item 7 have been computed
# Metrics for Item 8 have been computed
# Metrics for Item 9 have been computed
# Metrics for Item 10 have been computed
# Metrics for Item 11 have been computed
# Metrics for Item 12 have been computed
# Metrics for Item 13 have been computed
# Metrics for Item 14 have been computed
# Metrics for Item 15 have been computed
# Metrics for Item 16 have been computed
# Metrics for Item 17 have been computed
# Metrics for Item 18 have been computed
# Metrics for Item 19 have been computed
# Metrics for Item 20 have been computed
# Metrics for Item 21 have been computed
# Metrics for Item 22 have been computed
# Metrics for Item 23 have been computed
# Metrics for Item 24 have been computed
# Metrics for Item 25 have been computed
# Metrics for Item 26 have been computed
# Metrics for Item 27 have been computed
# Metrics for Item 28 have been computed
# Metrics for Item 29 have been computed
# Metrics for Item 30 have been computed
# Metrics for Item 31 have been computed
# Metrics for Item 32 have been computed
# Metrics for Item 33 have been computed
# Metrics for Item 34 have been computed
# Metrics for Item 35 have been computed
# Metrics for Item 36 have been computed
# Metrics for Item 37 have been computed
# Metrics for Item 38 have been computed
# Metrics for Item 39 have been computed
# Metrics for Item 40 have been computed
# Metrics for Item 41 have been computed
# Metrics for Item 42 have been computed
# Metrics for Item 43 have been computed
# Metrics for Item 44 have been computed
# Metrics for Item 45 have been computed
# Metrics for Item 46 have been computed
# Metrics for Item 47 have been computed
# Metrics for Item 48 have been computed
# Metrics for Item 49 have been computed
# Metrics for Item 50 have been computed
# Metrics for Item 51 have been computed
# Metrics for Item 52 have been computed
# Metrics for Item 53 have been computed
# Metrics for Item 54 have been computed
# Metrics for Item 55 have been computed
# Metrics for Item 56 have been computed
# Metrics for Item 57 have been computed
# Metrics for Item 58 have been computed
# Metrics for Item 59 have been computed
# Metrics for Item 60 have been computed
# Metrics for Item 61 have been computed
# Metrics for Item 62 have been computed
# Metrics for Item 63 have been computed
# Metrics for Item 64 have been computed
# Metrics for Item 65 have been computed
# Metrics for Item 66 have been computed
# Metrics for Item 67 have been computed
# Metrics for Item 68 have been computed
# Metrics for Item 69 have been computed
# Metrics for Item 70 have been computed
# Metrics for Item 71 have been computed
# Metrics for Item 72 have been computed
# Metrics for Item 73 have been computed
# Metrics for Item 74 have been computed
# Metrics for Item 75 have been computed
# Metrics for Item 76 have been computed
# Metrics for Item 77 have been computed
# Metrics for Item 78 have been computed
# Metrics for Item 79 have been computed
# Metrics for Item 80 have been computed
# Metrics for Item 81 have been computed
# Metrics for Item 82 have been computed
# Metrics for Item 83 have been computed
# Metrics for Item 84 have been computed
# Metrics for Item 85 have been computed
# Metrics for Item 86 have been computed
# Metrics for Item 87 have been computed
# Metrics for Item 88 have been computed
# Metrics for Item 89 have been computed
# Metrics for Item 90 have been computed
# Metrics for Item 91 have been computed
# Metrics for Item 92 have been computed
# Metrics for Item 93 have been computed
# Metrics for Item 94 have been computed
# Metrics for Item 95 have been computed
# Metrics for Item 96 have been computed
# Metrics for Item 97 have been computed
# Metrics for Item 98 have been computed
# Metrics for Item 99 have been computed
# Metrics for Item 100 have been computed
# Metrics for Item 101 have been computed
# Metrics for Item 102 have been computed
# Metrics for Item 103 have been computed
# Metrics for Item 104 have been computed
# Metrics for Item 105 have been computed
# Metrics for Item 106 have been computed
# Metrics for Item 107 have been computed
# Metrics for Item 108 have been computed
# Metrics for Item 109 have been computed
# Metrics for Item 110 have been computed
# Metrics for Item 111 have been computed
# Metrics for Item 112 have been computed
# Metrics for Item 113 have been computed
# Metrics for Item 114 have been computed
# Metrics for Item 115 have been computed
# Metrics for Item 116 have been computed
# Metrics for Item 117 have been computed
# Metrics for Item 118 have been computed
# Metrics for Item 119 have been computed
# Metrics for Item 120 have been computed
# Metrics for Item 121 have been computed
# Metrics for Item 122 have been computed
# Metrics for Item 123 have been computed
# Metrics for Item 124 have been computed
# Metrics for Item 125 have been computed
# Metrics for Item 126 have been computed
# Metrics for Item 127 have been computed
# Metrics for Item 128 have been computed
# Metrics for Item 129 have been computed
# Metrics for Item 130 have been computed
# Metrics for Item 131 have been computed
# Metrics for Item 132 have been computed
# Metrics for Item 133 have been computed
# Metrics for Item 134 have been computed
# Metrics for Item 135 have been computed
# Metrics for Item 136 have been computed
# Metrics for Item 137 have been computed
# Metrics for Item 138 have been computed
# Metrics for Item 139 have been computed
# Metrics for Item 140 have been computed
# Metrics for Item 141 have been computed
# Metrics for Item 142 have been computed
# Metrics for Item 143 have been computed
# Metrics for Item 144 have been computed
# Metrics for Item 145 have been computed
# Metrics for Item 146 have been computed
# Metrics for Item 147 have been computed
# Metrics for Item 148 have been computed
# Metrics for Item 149 have been computed
# Metrics for Item 150 have been computed
# Metrics for Item 151 have been computed
# Metrics for Item 152 have been computed
# Metrics for Item 153 have been computed
# Metrics for Item 154 have been computed
# Metrics for Item 155 have been computed
# Metrics for Item 156 have been computed
# Metrics for Item 157 have been computed
# Metrics for Item 158 have been computed
# Metrics for Item 159 have been computed
# Metrics for Item 160 have been computed
# Metrics for Item 161 have been computed
# Metrics for Item 162 have been computed
# Metrics for Item 163 have been computed
# Metrics for Item 164 have been computed
# Metrics for Item 165 have been computed
# Metrics for Item 166 have been computed
# Metrics for Item 167 have been computed
# Metrics for Item 168 have been computed
# Metrics for Item 169 have been computed
# Metrics for Item 170 have been computed
# Metrics for Item 171 have been computed
# Metrics for Item 172 have been computed
# Metrics for Item 173 have been computed
# Metrics for Item 174 have been computed
# Metrics for Item 175 have been computed
# Metrics for Item 176 have been computed
# Metrics for Item 177 have been computed
# Metrics for Item 178 have been computed
# Metrics for Item 179 have been computed
# Metrics for Item 180 have been computed
# Metrics for Item 181 have been computed
# Metrics for Item 182 have been computed
# Metrics for Item 183 have been computed
# Metrics for Item 184 have been computed
# Metrics for Item 185 have been computed
# Metrics for Item 186 have been computed
# Metrics for Item 187 have been computed
# Metrics for Item 188 have been computed
# Metrics for Item 189 have been computed
# Metrics for Item 190 have been computed
# Metrics for Item 191 have been computed
# Metrics for Item 192 have been computed
# Metrics for Item 193 have been computed
# Metrics for Item 194 have been computed
# Metrics for Item 195 have been computed
# Metrics for Item 196 have been computed
# Metrics for Item 197 have been computed
# Metrics for Item 198 have been computed
# Metrics for Item 199 have been computed
# Metrics for Item 200 have been computed
# Metrics for Item 201 have been computed
# Metrics for Item 202 have been computed
# Metrics for Item 203 have been computed
# Metrics for Item 204 have been computed
# Metrics for Item 205 have been computed
# Metrics for Item 206 have been computed
# Metrics for Item 207 have been computed
# Metrics for Item 208 have been computed
# Metrics for Item 209 have been computed
# Metrics for Item 210 have been computed
# Metrics for Item 211 have been computed
# Metrics for Item 212 have been computed
# Metrics for Item 213 have been computed
# Metrics for Item 214 have been computed
# Metrics for Item 215 have been computed
# Metrics for Item 216 have been computed
# Metrics for Item 217 have been computed
# Metrics for Item 218 have been computed
# Metrics for Item 219 have been computed
# Metrics for Item 220 have been computed
# Metrics for Item 221 have been computed
# Metrics for Item 222 have been computed
# Metrics for Item 223 have been computed
# Metrics for Item 224 have been computed
# Metrics for Item 225 have been computed
# Metrics for Item 226 have been computed
# Metrics for Item 227 have been computed
# Metrics for Item 228 have been computed
# Metrics for Item 229 have been computed
# Metrics for Item 230 have been computed
# Metrics for Item 231 have been computed
# Metrics for Item 232 have been computed
# Metrics for Item 233 have been computed
# Metrics for Item 234 have been computed
# Metrics for Item 235 have been computed
# Metrics for Item 236 have been computed
# Metrics for Item 237 have been computed
# Metrics for Item 238 have been computed
# Metrics for Item 239 have been computed
# Metrics for Item 240 have been computed
# Metrics for Item 241 have been computed
# Metrics for Item 242 have been computed
# Metrics for Item 243 have been computed
# Metrics for Item 244 have been computed
# Metrics for Item 245 have been computed
# Metrics for Item 246 have been computed
# Metrics for Item 247 have been computed
# Metrics for Item 248 have been computed
# Metrics for Item 249 have been computed
# Metrics for Item 250 have been computed
# Metrics for Item 251 have been computed
# Metrics for Item 252 have been computed
# Metrics for Item 253 have been computed
# Metrics for Item 254 have been computed
# Metrics for Item 255 have been computed
# Metrics for Item 256 have been computed
# Metrics for Item 257 have been computed
# Metrics for Item 258 have been computed
# Metrics for Item 259 have been computed
# Metrics for Item 260 have been computed
# Metrics for Item 261 have been computed
# Metrics for Item 262 have been computed
# Metrics for Item 263 have been computed
# Metrics for Item 264 have been computed
# Metrics for Item 265 have been computed
# Metrics for Item 266 have been computed
# Metrics for Item 267 have been computed
# Metrics for Item 268 have been computed
# Metrics for Item 269 have been computed
# Metrics for Item 270 have been computed
# Metrics for Item 271 have been computed
# Metrics for Item 272 have been computed
# Metrics for Item 273 have been computed
# Metrics for Item 274 have been computed
# Metrics for Item 275 have been computed
# Metrics for Item 276 have been computed
# Metrics for Item 277 have been computed
# Metrics for Item 278 have been computed
# Metrics for Item 279 have been computed
# Metrics for Item 280 have been computed
# Metrics for Item 281 have been computed
# Metrics for Item 282 have been computed
# Metrics for Item 283 have been computed
# Metrics for Item 284 have been computed
# Metrics for Item 285 have been computed
# Metrics for Item 286 have been computed
# Metrics for Item 287 have been computed
# Metrics for Item 288 have been computed
# Metrics for Item 289 have been computed
# Metrics for Item 290 have been computed
# Metrics for Item 291 have been computed
# Metrics for Item 292 have been computed
# Metrics for Item 293 have been computed
# Metrics for Item 294 have been computed
# Metrics for Item 295 have been computed
# Metrics for Item 296 have been computed
# Metrics for Item 297 have been computed
# Metrics for Item 298 have been computed
# Metrics for Item 299 have been computed
# Metrics for Item 300 have been computed
# Metrics for Item 301 have been computed
# Metrics for Item 302 have been computed
# Metrics for Item 303 have been computed
# Metrics for Item 304 have been computed
# Metrics for Item 305 have been computed
# Metrics for Item 306 have been computed
# Metrics for Item 307 have been computed
# Metrics for Item 308 have been computed
# Metrics for Item 309 have been computed
# Metrics for Item 310 have been computed
# Metrics for Item 311 have been computed
# Metrics for Item 312 have been computed
# Metrics for Item 313 have been computed
# Metrics for Item 314 have been computed
# Metrics for Item 315 have been computed
# Metrics for Item 316 have been computed
# Metrics for Item 317 have been computed
# Metrics for Item 318 have been computed
# Metrics for Item 319 have been computed
# Metrics for Item 320 have been computed
# Metrics for Item 321 have been computed
# Metrics for Item 322 have been computed
# Metrics for Item 323 have been computed
# Metrics for Item 324 have been computed
# Metrics for Item 325 have been computed
# Metrics for Item 326 have been computed
# Metrics for Item 327 have been computed
# Metrics for Item 328 have been computed
# Metrics for Item 329 have been computed
# Metrics for Item 330 have been computed
# Metrics for Item 331 have been computed
# Metrics for Item 332 have been computed
# Metrics for Item 333 have been computed
# Metrics for Item 334 have been computed
# Metrics for Item 335 have been computed
# Metrics for Item 336 have been computed
# Metrics for Item 337 have been computed
# Metrics for Item 338 have been computed
# Metrics for Item 339 have been computed
# Metrics for Item 340 have been computed
# Metrics for Item 341 have been computed
# Metrics for Item 342 have been computed
# Metrics for Item 343 have been computed
# Metrics for Item 344 have been computed
# Metrics for Item 345 have been computed
# Metrics for Item 346 have been computed
# Metrics for Item 347 have been computed
# Metrics for Item 348 have been computed
# Metrics for Item 349 have been computed
# Metrics for Item 350 have been computed
# Metrics for Item 351 have been computed
# Metrics for Item 352 have been computed
# Metrics for Item 353 have been computed
# Metrics for Item 354 have been computed
# Metrics for Item 355 have been computed
# Metrics for Item 356 have been computed
# Metrics for Item 357 have been computed
# Metrics for Item 358 have been computed
# Metrics for Item 359 have been computed
# Metrics for Item 360 have been computed
# Metrics for Item 361 have been computed
# Metrics for Item 362 have been computed
# Metrics for Item 363 have been computed
# Metrics for Item 364 have been computed
# Metrics for Item 365 have been computed
# Metrics for Item 366 have been computed
# Metrics for Item 367 have been computed
# Metrics for Item 368 have been computed
# Metrics for Item 369 have been computed
# Metrics for Item 370 have been computed
# Metrics for Item 371 have been computed
# Metrics for Item 372 have been computed
# Metrics for Item 373 have been computed
# Metrics for Item 374 have been computed
# Metrics for Item 375 have been computed
# Metrics for Item 376 have been computed
# Metrics for Item 377 have been computed
# Metrics for Item 378 have been computed
# Metrics for Item 379 have been computed
# Metrics for Item 380 have been computed
# Metrics for Item 381 have been computed
# Metrics for Item 382 have been computed
# Metrics for Item 383 have been computed
# Metrics for Item 384 have been computed
# Metrics for Item 385 have been computed
# Metrics for Item 386 have been computed
# Metrics for Item 387 have been computed
# Metrics for Item 388 have been computed
# Metrics for Item 389 have been computed
# Metrics for Item 390 have been computed
# Metrics for Item 391 have been computed
# Metrics for Item 392 have been computed
# Metrics for Item 393 have been computed
# Metrics for Item 394 have been computed
# Metrics for Item 395 have been computed
# Metrics for Item 396 have been computed
# Metrics for Item 397 have been computed
# Metrics for Item 398 have been computed
# Metrics for Item 399 have been computed
# Metrics for Item 400 have been computed
# Metrics for Item 401 have been computed
# Metrics for Item 402 have been computed
# Metrics for Item 403 have been computed
# Metrics for Item 404 have been computed
# Metrics for Item 405 have been computed
# Metrics for Item 406 have been computed
# Metrics for Item 407 have been computed
# Metrics for Item 408 have been computed
# Metrics for Item 409 have been computed
# Metrics for Item 410 have been computed
# Metrics for Item 411 have been computed
# Metrics for Item 412 have been computed
# Metrics for Item 413 have been computed
# Metrics for Item 414 have been computed
# Metrics for Item 415 have been computed
# Metrics for Item 416 have been computed
# Metrics for Item 417 have been computed
# Metrics for Item 418 have been computed
# Metrics for Item 419 have been computed
# Metrics for Item 420 have been computed
# Metrics for Item 421 have been computed
# Metrics for Item 422 have been computed
# Metrics for Item 423 have been computed
# Metrics for Item 424 have been computed
# Metrics for Item 425 have been computed
# Metrics for Item 426 have been computed
# Metrics for Item 427 have been computed
# Metrics for Item 428 have been computed
# Metrics for Item 429 have been computed
# Metrics for Item 430 have been computed
# Metrics for Item 431 have been computed
# Metrics for Item 432 have been computed
# Metrics for Item 433 have been computed
# Metrics for Item 434 have been computed
# Metrics for Item 435 have been computed
# Metrics for Item 436 have been computed
# Metrics for Item 437 have been computed
# Metrics for Item 438 have been computed
# Metrics for Item 439 have been computed
# Metrics for Item 440 have been computed
# Metrics for Item 441 have been computed
# Metrics for Item 442 have been computed
# Metrics for Item 443 have been computed
# Metrics for Item 444 have been computed
# Metrics for Item 445 have been computed
# Metrics for Item 446 have been computed
# Metrics for Item 447 have been computed
# Metrics for Item 448 have been computed
# Metrics for Item 449 have been computed
# Metrics for Item 450 have been computed
# Metrics for Item 451 have been computed
# Metrics for Item 452 have been computed
# Metrics for Item 453 have been computed
# Metrics for Item 454 have been computed
# Metrics for Item 455 have been computed
# Metrics for Item 456 have been computed
# Metrics for Item 457 have been computed
# Metrics for Item 458 have been computed
# Metrics for Item 459 have been computed
# Metrics for Item 460 have been computed
# Metrics for Item 461 have been computed
# Metrics for Item 462 have been computed
# Metrics for Item 463 have been computed
# Metrics for Item 464 have been computed
# Metrics for Item 465 have been computed
# Metrics for Item 466 have been computed
# Metrics for Item 467 have been computed
# Metrics for Item 468 have been computed
# Metrics for Item 469 have been computed
# Metrics for Item 470 have been computed
# Metrics for Item 471 have been computed
# Metrics for Item 472 have been computed
# Metrics for Item 473 have been computed
# Metrics for Item 474 have been computed
# Metrics for Item 475 have been computed
# Metrics for Item 476 have been computed
# Metrics for Item 477 have been computed
# Metrics for Item 478 have been computed
# Metrics for Item 479 have been computed
# Metrics for Item 480 have been computed
# Metrics for Item 481 have been computed
# Metrics for Item 482 have been computed
# Metrics for Item 483 have been computed
# Metrics for Item 484 have been computed
# Metrics for Item 485 have been computed
# Metrics for Item 486 have been computed
# Metrics for Item 487 have been computed
# Metrics for Item 488 have been computed
# Metrics for Item 489 have been computed
# Metrics for Item 490 have been computed
# Metrics for Item 491 have been computed
# Metrics for Item 492 have been computed
# Metrics for Item 493 have been computed
# Metrics for Item 494 have been computed
# Metrics for Item 495 have been computed
# Metrics for Item 496 have been computed
# Metrics for Item 497 have been computed
# Metrics for Item 498 have been computed
# Metrics for Item 499 have been computed
# Metrics for Item 500 have been computed
# Metrics for Item 501 have been computed
# Metrics for Item 502 have been computed
# Metrics for Item 503 have been computed
# Metrics for Item 504 have been computed
# Metrics for Item 505 have been computed
# Metrics for Item 506 have been computed
# Metrics for Item 507 have been computed
# Metrics for Item 508 have been computed
# Metrics for Item 509 have been computed
# Metrics for Item 510 have been computed
# Metrics for Item 511 have been computed
# Metrics for Item 512 have been computed
# Metrics for Item 513 have been computed
# Metrics for Item 514 have been computed
# Metrics for Item 515 have been computed
# Metrics for Item 516 have been computed
# Metrics for Item 517 have been computed
# Metrics for Item 518 have been computed
# Metrics for Item 519 have been computed
# Metrics for Item 520 have been computed
# Metrics for Item 521 have been computed
# Metrics for Item 522 have been computed
# Metrics for Item 523 have been computed
# Metrics for Item 524 have been computed
# Metrics for Item 525 have been computed
# Metrics for Item 526 have been computed
# Metrics for Item 527 have been computed
# Metrics for Item 528 have been computed
# Metrics for Item 529 have been computed
# Metrics for Item 530 have been computed
# Metrics for Item 531 have been computed
# Metrics for Item 532 have been computed
# Metrics for Item 533 have been computed
# Metrics for Item 534 have been computed
# Metrics for Item 535 have been computed
# Metrics for Item 536 have been computed
# Metrics for Item 537 have been computed
# Metrics for Item 538 have been computed
# Metrics for Item 539 have been computed
# Metrics for Item 540 have been computed
# Metrics for Item 541 have been computed
# Metrics for Item 542 have been computed
# Metrics for Item 543 have been computed
# Metrics for Item 544 have been computed
# Metrics for Item 545 have been computed
# Metrics for Item 546 have been computed
# Metrics for Item 547 have been computed
# Metrics for Item 548 have been computed
# Metrics for Item 549 have been computed
# Metrics for Item 550 have been computed
# Metrics for Item 551 have been computed
# Metrics for Item 552 have been computed
# Metrics for Item 553 have been computed
# Metrics for Item 554 have been computed
# Metrics for Item 555 have been computed
# Metrics for Item 556 have been computed
# Metrics for Item 557 have been computed
# Metrics for Item 558 have been computed
# Metrics for Item 559 have been computed
# Metrics for Item 560 have been computed
# Metrics for Item 561 have been computed
# Metrics for Item 562 have been computed
# Metrics for Item 563 have been computed
# Metrics for Item 564 have been computed
# Metrics for Item 565 have been computed
# Metrics for Item 566 have been computed
# Metrics for Item 567 have been computed
# Metrics for Item 568 have been computed
# Metrics for Item 569 have been computed
# Metrics for Item 570 have been computed
# Metrics for Item 571 have been computed
# Metrics for Item 572 have been computed
# Metrics for Item 573 have been computed
# Metrics for Item 574 have been computed
# Metrics for Item 575 have been computed
# Metrics for Item 576 have been computed
# Metrics for Item 577 have been computed
# Metrics for Item 578 have been computed
# Metrics for Item 579 have been computed
# Metrics for Item 580 have been computed
# Metrics for Item 581 have been computed
# Metrics for Item 582 have been computed
# Metrics for Item 583 have been computed
# Metrics for Item 584 have been computed
# Metrics for Item 585 have been computed
# Metrics for Item 586 have been computed
# Metrics for Item 587 have been computed
# Metrics for Item 588 have been computed
# Metrics for Item 589 have been computed
# Metrics for Item 590 have been computed
# Metrics for Item 591 have been computed
# Metrics for Item 592 have been computed
# Metrics for Item 593 have been computed
# Metrics for Item 594 have been computed
# Metrics for Item 595 have been computed
# Metrics for Item 596 have been computed
# Metrics for Item 597 have been computed
# Metrics for Item 598 have been computed
# Metrics for Item 599 have been computed
# Metrics for Item 600 have been computed
# Metrics for Item 601 have been computed
# Metrics for Item 602 have been computed
# Metrics for Item 603 have been computed
# Metrics for Item 604 have been computed
# Metrics for Item 605 have been computed
# Metrics for Item 606 have been computed
# Metrics for Item 607 have been computed
# Metrics for Item 608 have been computed
# Metrics for Item 609 have been computed
# Metrics for Item 610 have been computed
# Metrics for Item 611 have been computed
# Metrics for Item 612 have been computed
# Metrics for Item 613 have been computed
# Metrics for Item 614 have been computed
# Metrics for Item 615 have been computed
# Metrics for Item 616 have been computed
# Metrics for Item 617 have been computed
# Metrics for Item 618 have been computed
# Metrics for Item 619 have been computed
# Metrics for Item 620 have been computed
# Metrics for Item 621 have been computed
# Metrics for Item 622 have been computed
# Metrics for Item 623 have been computed
# Metrics for Item 624 have been computed
# Metrics for Item 625 have been computed
# Metrics for Item 626 have been computed
# Metrics for Item 627 have been computed
# Metrics for Item 628 have been computed
# Metrics for Item 629 have been computed
# Metrics for Item 630 have been computed
# Metrics for Item 631 have been computed
# Metrics for Item 632 have been computed
# Metrics for Item 633 have been computed
# Metrics for Item 634 have been computed
# Metrics for Item 635 have been computed
# Metrics for Item 636 have been computed
# Metrics for Item 637 have been computed
# Metrics for Item 638 have been computed
# Metrics for Item 639 have been computed
# Metrics for Item 640 have been computed
# Metrics for Item 641 have been computed
# Metrics for Item 642 have been computed
# Metrics for Item 643 have been computed
# Metrics for Item 644 have been computed
# Metrics for Item 645 have been computed
# Metrics for Item 646 have been computed
# Metrics for Item 647 have been computed
# Metrics for Item 648 have been computed
# Metrics for Item 649 have been computed
# Metrics for Item 650 have been computed
# Metrics for Item 651 have been computed
# Metrics for Item 652 have been computed
# Metrics for Item 653 have been computed
# Metrics for Item 654 have been computed
# Metrics for Item 655 have been computed
# Metrics for Item 656 have been computed
# Metrics for Item 657 have been computed
# Metrics for Item 658 have been computed
# Metrics for Item 659 have been computed
# Metrics for Item 660 have been computed
# Metrics for Item 661 have been computed
# Metrics for Item 662 have been computed
# Metrics for Item 663 have been computed
# Metrics for Item 664 have been computed
# Metrics for Item 665 have been computed
# Metrics for Item 666 have been computed
# Metrics for Item 667 have been computed
# Metrics for Item 668 have been computed
# Metrics for Item 669 have been computed
# Metrics for Item 670 have been computed
# Metrics for Item 671 have been computed
# Metrics for Item 672 have been computed
# Metrics for Item 673 have been computed
# Metrics for Item 674 have been computed
# Metrics for Item 675 have been computed
# Metrics for Item 676 have been computed
# Metrics for Item 677 have been computed
# Metrics for Item 678 have been computed
# Metrics for Item 679 have been computed
# Metrics for Item 680 have been computed
# Metrics for Item 681 have been computed
# Metrics for Item 682 have been computed
# Metrics for Item 683 have been computed
# Metrics for Item 684 have been computed
# Metrics for Item 685 have been computed
# Metrics for Item 686 have been computed
# Metrics for Item 687 have been computed
# Metrics for Item 688 have been computed
# Metrics for Item 689 have been computed
# Metrics for Item 690 have been computed
# Metrics for Item 691 have been computed
# Metrics for Item 692 have been computed
# Metrics for Item 693 have been computed
# Metrics for Item 694 have been computed
# Metrics for Item 695 have been computed
# Metrics for Item 696 have been computed
# Metrics for Item 697 have been computed
# Metrics for Item 698 have been computed
# Metrics for Item 699 have been computed
# Metrics for Item 700 have been computed
# Metrics for Item 701 have been computed
# Metrics for Item 702 have been computed
# Metrics for Item 703 have been computed
# Metrics for Item 704 have been computed
# Metrics for Item 705 have been computed
# Metrics for Item 706 have been computed
# Metrics for Item 707 have been computed
# Metrics for Item 708 have been computed
# Metrics for Item 709 have been computed
# Metrics for Item 710 have been computed
# Metrics for Item 711 have been computed
# Metrics for Item 712 have been computed
# Metrics for Item 713 have been computed
# Metrics for Item 714 have been computed
# Metrics for Item 715 have been computed
# Metrics for Item 716 have been computed
# Metrics for Item 717 have been computed
# Metrics for Item 718 have been computed
# Metrics for Item 719 have been computed
# Metrics for Item 720 have been computed
# Metrics for Item 721 have been computed
# Metrics for Item 722 have been computed
# Metrics for Item 723 have been computed
# Metrics for Item 724 have been computed
# Metrics for Item 725 have been computed
# Metrics for Item 726 have been computed
# Metrics for Item 727 have been computed
# Metrics for Item 728 have been computed
# Metrics for Item 729 have been computed
# Metrics for Item 730 have been computed
# Metrics for Item 731 have been computed
# Metrics for Item 732 have been computed
# Metrics for Item 733 have been computed
# Metrics for Item 734 have been computed
# Metrics for Item 735 have been computed
# Metrics for Item 736 have been computed
# Metrics for Item 737 have been computed
# Metrics for Item 738 have been computed
# Metrics for Item 739 have been computed
# Metrics for Item 740 have been computed
# Metrics for Item 741 have been computed
# Metrics for Item 742 have been computed
# Metrics for Item 743 have been computed
# Metrics for Item 744 have been computed
# Metrics for Item 745 have been computed
# Metrics for Item 746 have been computed
# Metrics for Item 747 have been computed
# Metrics for Item 748 have been computed
# Metrics for Item 749 have been computed
# Metrics for Item 750 have been computed
# Metrics for Item 751 have been computed
# Metrics for Item 752 have been computed
# Metrics for Item 753 have been computed
# Metrics for Item 754 have been computed
# Metrics for Item 755 have been computed
# Metrics for Item 756 have been computed
# Metrics for Item 757 have been computed
# Metrics for Item 758 have been computed
# Metrics for Item 759 have been computed
# Metrics for Item 760 have been computed
# Metrics for Item 761 have been computed
# Metrics for Item 762 have been computed
# Metrics for Item 763 have been computed
# Metrics for Item 764 have been computed
# Metrics for Item 765 have been computed
# Metrics for Item 766 have been computed
# Metrics for Item 767 have been computed
# Metrics for Item 768 have been computed
# Metrics for Item 769 have been computed
# Metrics for Item 770 have been computed
# Metrics for Item 771 have been computed
# Metrics for Item 772 have been computed
# Metrics for Item 773 have been computed
# Metrics for Item 774 have been computed
# Metrics for Item 775 have been computed
# Metrics for Item 776 have been computed
# Metrics for Item 777 have been computed
# Metrics for Item 778 have been computed
# Metrics for Item 779 have been computed
# Metrics for Item 780 have been computed
# Metrics for Item 781 have been computed
# Metrics for Item 782 have been computed
# Metrics for Item 783 have been computed
# Metrics for Item 784 have been computed
# Metrics for Item 785 have been computed
# Metrics for Item 786 have been computed
# Metrics for Item 787 have been computed
# Metrics for Item 788 have been computed
# Metrics for Item 789 have been computed
# Metrics for Item 790 have been computed
# Metrics for Item 791 have been computed
# Metrics for Item 792 have been computed
# Metrics for Item 793 have been computed
# Metrics for Item 794 have been computed
# Metrics for Item 795 have been computed
# Metrics for Item 796 have been computed
# Metrics for Item 797 have been computed
# Metrics for Item 798 have been computed
# Metrics for Item 799 have been computed
# Metrics for Item 800 have been computed
# Metrics for Item 801 have been computed
# Metrics for Item 802 have been computed
# Metrics for Item 803 have been computed
# Metrics for Item 804 have been computed
# Metrics for Item 805 have been computed
# Metrics for Item 806 have been computed
# Metrics for Item 807 have been computed
# Metrics for Item 808 have been computed
# Metrics for Item 809 have been computed
# Metrics for Item 810 have been computed
# Metrics for Item 811 have been computed
# Metrics for Item 812 have been computed
# Metrics for Item 813 have been computed
# Metrics for Item 814 have been computed
# Metrics for Item 815 have been computed
# Metrics for Item 816 have been computed
# Metrics for Item 817 have been computed
# Metrics for Item 818 have been computed
# Metrics for Item 819 have been computed
# Metrics for Item 820 have been computed
# Metrics for Item 821 have been computed
# Metrics for Item 822 have been computed
# Metrics for Item 823 have been computed
# Metrics for Item 824 have been computed
# Metrics for Item 825 have been computed
# Metrics for Item 826 have been computed
# Metrics for Item 827 have been computed
# Metrics for Item 828 have been computed
# Metrics for Item 829 have been computed
# Metrics for Item 830 have been computed
# Metrics for Item 831 have been computed
# Metrics for Item 832 have been computed
# Metrics for Item 833 have been computed
# Metrics for Item 834 have been computed
# Metrics for Item 835 have been computed
# Metrics for Item 836 have been computed
# Metrics for Item 837 have been computed
# Metrics for Item 838 have been computed
# Metrics for Item 839 have been computed
# Metrics for Item 840 have been computed
# Metrics for Item 841 have been computed
# Metrics for Item 842 have been computed
# Metrics for Item 843 have been computed
# Metrics for Item 844 have been computed
# Metrics for Item 845 have been computed
# Metrics for Item 846 have been computed
# Metrics for Item 847 have been computed
# Metrics for Item 848 have been computed
# Metrics for Item 849 have been computed
# Metrics for Item 850 have been computed
# Metrics for Item 851 have been computed
# Metrics for Item 852 have been computed
# Metrics for Item 853 have been computed
# Metrics for Item 854 have been computed
# Metrics for Item 855 have been computed
# Metrics for Item 856 have been computed
# Metrics for Item 857 have been computed
# Metrics for Item 858 have been computed
# Metrics for Item 859 have been computed
# Metrics for Item 860 have been computed
# Metrics for Item 861 have been computed
# Metrics for Item 862 have been computed
# Metrics for Item 863 have been computed
# Metrics for Item 864 have been computed
# Metrics for Item 865 have been computed
# Metrics for Item 866 have been computed
# Metrics for Item 867 have been computed
# Metrics for Item 868 have been computed
# Metrics for Item 869 have been computed
# Metrics for Item 870 have been computed
# Metrics for Item 871 have been computed
# Metrics for Item 872 have been computed
# Metrics for Item 873 have been computed
# Metrics for Item 874 have been computed
# Metrics for Item 875 have been computed
# Metrics for Item 876 have been computed
# Metrics for Item 877 have been computed
# Metrics for Item 878 have been computed
# Metrics for Item 879 have been computed
# Metrics for Item 880 have been computed
# Metrics for Item 881 have been computed
# Metrics for Item 882 have been computed
# Metrics for Item 883 have been computed
# Metrics for Item 884 have been computed
# Metrics for Item 885 have been computed
# Metrics for Item 886 have been computed
# Metrics for Item 887 have been computed
# Metrics for Item 888 have been computed
# Metrics for Item 889 have been computed
# Metrics for Item 890 have been computed
# Metrics for Item 891 have been computed
# Metrics for Item 892 have been computed
# Metrics for Item 893 have been computed
# Metrics for Item 894 have been computed
# Metrics for Item 895 have been computed
# Metrics for Item 896 have been computed
# Metrics for Item 897 have been computed
# Metrics for Item 898 have been computed
# Metrics for Item 899 have been computed
# Metrics for Item 900 have been computed
# Metrics for Item 901 have been computed
# Metrics for Item 902 have been computed
# Metrics for Item 903 have been computed
# Metrics for Item 904 have been computed
# Metrics for Item 905 have been computed
# Metrics for Item 906 have been computed
# Metrics for Item 907 have been computed
# Metrics for Item 908 have been computed
# Metrics for Item 909 have been computed
# Metrics for Item 910 have been computed
# Metrics for Item 911 have been computed
# Metrics for Item 912 have been computed
# Metrics for Item 913 have been computed
# Metrics for Item 914 have been computed
# Metrics for Item 915 have been computed
# Metrics for Item 916 have been computed
# Metrics for Item 917 have been computed
# Metrics for Item 918 have been computed
# Metrics for Item 919 have been computed
# Metrics for Item 920 have been computed
# Metrics for Item 921 have been computed
# Metrics for Item 922 have been computed
# Metrics for Item 923 have been computed
# Metrics for Item 924 have been computed
# Metrics for Item 925 have been computed
# Metrics for Item 926 have been computed
# Metrics for Item 927 have been computed
# Metrics for Item 928 have been computed
# Metrics for Item 929 have been computed
# Metrics for Item 930 have been computed
# Metrics for Item 931 have been computed
# Metrics for Item 932 have been computed
# Metrics for Item 933 have been computed
# Metrics for Item 934 have been computed
# Metrics for Item 935 have been computed
# Metrics for Item 936 have been computed
# Metrics for Item 937 have been computed
# Metrics for Item 938 have been computed
# Metrics for Item 939 have been computed
# Metrics for Item 940 have been computed
# Metrics for Item 941 have been computed
# Metrics for Item 942 have been computed
# Metrics for Item 943 have been computed
# Metrics for Item 944 have been computed
# Metrics for Item 945 have been computed
# Metrics for Item 946 have been computed
# Metrics for Item 947 have been computed
# Metrics for Item 948 have been computed
# Metrics for Item 949 have been computed
# Metrics for Item 950 have been computed
# Metrics for Item 951 have been computed
# Metrics for Item 952 have been computed
# Metrics for Item 953 have been computed
# Metrics for Item 954 have been computed
# Metrics for Item 955 have been computed
# Metrics for Item 956 have been computed
# Metrics for Item 957 have been computed
# Metrics for Item 958 have been computed
# Metrics for Item 959 have been computed
# Metrics for Item 960 have been computed
# Metrics for Item 961 have been computed
# Metrics for Item 962 have been computed
# Metrics for Item 963 have been computed
# Metrics for Item 964 have been computed
# Metrics for Item 965 have been computed
# Metrics for Item 966 have been computed
# Metrics for Item 967 have been computed
# Metrics for Item 968 have been computed
# Metrics for Item 969 have been computed
# Metrics for Item 970 have been computed
# Metrics for Item 971 have been computed
# Metrics for Item 972 have been computed
# Metrics for Item 973 have been computed
# Metrics for Item 974 have been computed
# Metrics for Item 975 have been computed
# Metrics for Item 976 have been computed
# Metrics for Item 977 have been computed
# Metrics for Item 978 have been computed
# Metrics for Item 979 have been computed
# Metrics for Item 980 have been computed
# Metrics for Item 981 have been computed
# Metrics for Item 982 have been computed
# Metrics for Item 983 have been computed
# Metrics for Item 984 have been computed
# Metrics for Item 985 have been computed
# Metrics for Item 986 have been computed
# Metrics for Item 987 have been computed
# Metrics for Item 988 have been computed
# Metrics for Item 989 have been computed
# Metrics for Item 990 have been computed
# Metrics for Item 991 have been computed
# Metrics for Item 992 have been computed
# Metrics for Item 993 have been computed
# Metrics for Item 994 have been computed
# Metrics for Item 995 have been computed
# Metrics for Item 996 have been computed
# Metrics for Item 997 have been computed
# Metrics for Item 998 have been computed
# Metrics for Item 999 have been computed
# Metrics for Item 1000 have been computed

# %% [markdown]
# ### Data Transformations

# %%
### Transforming itemprice column into dollar-cent format for sponsored items 
itemprices_s_modified = []
for i in range(0,len(itemprices_s)):
    itemprice_new = re.findall(r'(\d+[.,]\d+)',itemprices_s[i])[0]
    itemprice_new = itemprice_new.replace(",","")
    itemprice_new = int(float(itemprice_new)*100)
    itemprices_s_modified.append(itemprice_new)

### Transforming itemprice column into dollar-cent format for non-sponsored items 
itemprices_ns_modified = []
for i in range(0,len(itemprices_ns)):
    try:
        itemprice_new = re.findall(r'(\d+[.,]\d+)',itemprices_ns[i])[0]
        itemprice_new = itemprice_new.replace(",","")
        itemprice_new = int(float(itemprice_new)*100)
    except IndexError:
        itemprice_new = None
    itemprices_ns_modified.append(itemprice_new)

# %%
### Transforming items-sold into digits format for sponsored items 
itemsold_re = re.compile(r'([0-9,]+).*')
itemssold_s_modified = []
for i in range(0,len(itemssold_s)):
    if (itemssold_s[i]!=None):
        itemsold_new = itemsold_re.sub(r'\1',itemssold_s[i])
        itemsold_new = itemsold_new.replace(",","")
    else:
        itemsold_new = None
    itemssold_s_modified.append(itemsold_new)

### Transforming items-sold into digits format for non-sponsored items 
itemssold_ns_modified = []
for i in range(0,len(itemssold_ns)):
    if (itemssold_ns[i]!=None):
        itemsold_new = itemsold_re.sub(r'\1',itemssold_ns[i])
        itemsold_new = itemsold_new.replace(",","")
    else:
        itemsold_new = None
    itemssold_ns_modified.append(itemsold_new)

# %%
### Transforming bestoffer into 1 or 0 for sponsored items 
bestoffers_s_modified = []
for i in range(0,len(bestoffers_s)):
    if bestoffers_s[i]!=None:
        bestoffer_new = 1
    else:
        bestoffer_new = 0 
    bestoffers_s_modified.append(bestoffer_new)

### Transforming bestoffer into 1 or 0 for non-sponsored items 
bestoffers_ns_modified = []
for i in range(0,len(bestoffers_ns)):
    if bestoffers_ns[i]!=None:
        bestoffer_new = 1
    else:
        bestoffer_new = 0 
    bestoffers_ns_modified.append(bestoffer_new)

# %%
### Cleaning title for sponsored items 
title_re = re.compile(r'^(Details about)(\s+)(\w.*)')
titles_s_modified = []
for i in range(0,len(titles_s)):
    title_new = title_re.sub(r'\3',titles_s[i])
    titles_s_modified.append(title_new)

### Cleaning title for non-sponsored items 
titles_ns_modified = []
for i in range(0,len(titles_ns)):
    title_new = title_re.sub(r'\3',titles_ns[i])
    titles_ns_modified.append(title_new)

# %%
### Transforming returns allowed into 1 or 0 for sponsored items 
returns_allowed_s_modified = []
for i in range(0,len(returns_allowed_s)):
    if('Seller does not accept returns' in str(returns_allowed_s[i])):
        returns_allowed_new = 0
    elif returns_allowed_s[i]==None:
        returns_allowed_new = 0
    else:
        returns_allowed_new = 1 
    returns_allowed_s_modified.append(returns_allowed_new)

### Transforming returns allowed into 1 or 0 for non-sponsored items    
returns_allowed_ns_modified = []
for i in range(0,len(returns_allowed_ns)):
    if('Seller does not accept returns' in str(returns_allowed_ns[i])):
        returns_allowed_new = 0
    elif returns_allowed_ns[i]==None:
        returns_allowed_new = 0
    else:
        returns_allowed_new = 1 
    returns_allowed_ns_modified.append(returns_allowed_new)

# %%
### Transforming shipping price into dollar-cent format when detected, 0 if Free, Null when not detected for sponsored items 
ship_price_re = re.compile(r'(\d+.\d+)')
shipping_prices_s_modified = []
for i in range(0,len(shipping_prices_s)):
    if ("$" in str(shipping_prices_s[i])):
        shippingprice_new = re.findall(r'(\d+.\d+)',shipping_prices_s[i])[0]
        shippingprice_new = int(float(shippingprice_new)*100)
    elif (('FAST' in str(shipping_prices_s[i])) or ('FREE' == str(shipping_prices_s[i]))):
        shippingprice_new = 0
    else:
        shippingprice_new = None
    shipping_prices_s_modified.append(shippingprice_new)

### Transforming shipping price into dollar-cent format when detected, 0 if Free, Null when not detected for non-sponsored items    
shipping_prices_ns_modified = []
for i in range(0,len(shipping_prices_ns)):
    if ("$" in str(shipping_prices_ns[i])):
        shippingprice_new = re.findall(r'(\d+.\d+)',shipping_prices_ns[i])[0]
        shippingprice_new = int(float(shippingprice_new)*100)
    elif (('FAST' in str(shipping_prices_ns[i])) or ('FREE' == str(shipping_prices_ns[i]))):
        shippingprice_new = 0
    else:
        shippingprice_new = None
    shipping_prices_ns_modified.append(shippingprice_new)

# %% [markdown]
# ### Creating eBay Database and eBay_items table in MYSQL

# %%
password_sql = ''
conn = pymysql.connect(host='localhost', user = 'root', password = password_sql)
cursor = conn.cursor()
DB = "eBay"
cursor.execute('DROP DATABASE IF EXISTS '+DB)
query_DB = "CREATE DATABASE IF NOT EXISTS " + DB + ";"
cursor.execute(query_DB)
Table = "eBay_items"
cursor.execute('DROP TABLE IF EXISTS ' + DB + '.' + Table)
query_Table = "CREATE TABLE IF NOT EXISTS " + DB + "." + Table + "(" + "itemid VARCHAR(13) NOT NULL PRIMARY KEY" + ", sellername VARCHAR(50)" + ", sellerscore int(7)" + ", itemprice int(6)" + ", itemsold int(4)" + ", bestoffer_flag boolean" + ", title VARCHAR(500)" + ", returnsallowed_flag boolean" + ", shippingprice int(10)" + ", conditions VARCHAR(50)" + ", sponsor_flag boolean" + ");"

cursor.execute(query_Table);
cursor.close()
conn.close()
# Out:
# C:\Users\Shrey Shah\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1008, "Can't drop database 'ebay'; database doesn't exist")
#   result = self._query(query)
# C:\Users\Shrey Shah\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1051, "Unknown table 'ebay.ebay_items'")
#   result = self._query(query)
# C:\Users\Shrey Shah\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1681, 'Integer display width is deprecated and will be removed in a future release.')
#   result = self._query(query)

# %% [markdown]
# ### Inserting data for Sponsored Items into Above Created Table

# %%
### Setup Connection with MySQL
conn = pymysql.connect(host='localhost', 
                       user = 'root', 
                       password = password_sql, 
                       database=DB)
cursor = conn.cursor()

### Run loop for inserting values into table
for i in tqdm(range(0,len(sponsored_items))):
    sql = "INSERT INTO "+ Table + ("(itemid,sellername,sellerscore,itemprice,itemsold,bestoffer_flag,title,returnsallowed_flag,shippingprice,conditions,sponsor_flag)"
        " VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, 1)")
    values = (sponsored_items[i], 
              sellernames_s[i], 
              sellerscores_s[i], 
              itemprices_s_modified[i], 
              itemssold_s_modified[i],
              bestoffers_s_modified[i], 
              titles_s_modified[i], 
              returns_allowed_s_modified[i], 
              shipping_prices_s_modified[i],
              conditions_s[i])
    
    # Calling the query to be executed 
    try:
        cursor.execute(sql, values)
        conn.commit()
    except pymysql.IntegrityError:
        print(str(sponsored_items[i]) + ' already exists in the database.')
# Out:
#  30%|████████████████████████                                                        | 39/130 [00:00<00:00, 148.98it/s]
# 181710891072 already exists in the database.
#  78%|█████████████████████████████████████████████████████████████▉                 | 102/130 [00:00<00:00, 162.95it/s]
# 262604947247 already exists in the database.
# 100%|███████████████████████████████████████████████████████████████████████████████| 130/130 [00:00<00:00, 189.11it/s]

# %% [markdown]
# ### Inserting data for Non-Sponsored Items into Above Created Table

# %%
# Setup connection with MySQL
conn = pymysql.connect(host='localhost', 
                       user = 'root', 
                       password = password_sql, 
                       database=DB)
cursor = conn.cursor()

### Run loop for inserting values into table
for i in tqdm(range(0,len(non_sponsored_items))):
    sql = "INSERT INTO "+ Table + ("(itemid,sellername,sellerscore,itemprice,itemsold,bestoffer_flag,title,returnsallowed_flag,shippingprice,conditions,sponsor_flag)"
        " VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, 0)")
    values = (non_sponsored_items[i], 
              sellernames_ns[i], 
              sellerscores_ns[i], 
              itemprices_ns_modified[i], 
              itemssold_ns_modified[i],
              bestoffers_ns_modified[i], 
              titles_ns_modified[i], 
              returns_allowed_ns_modified[i], 
              shipping_prices_ns_modified[i],
              conditions_ns[i])
    
    # Calling the query to be executed 
    try:
        cursor.execute(sql, values)
        conn.commit()
    except pymysql.IntegrityError:
        print(str(non_sponsored_items[i]) + ' already exists in the database.')
# Out:
#   8%|██████▍                                                                        | 82/1000 [00:00<00:05, 160.90it/s]
# 372729878272 already exists in the database.
#  19%|██████████████▌                                                               | 187/1000 [00:01<00:04, 170.00it/s]
# 181809799186 already exists in the database.
#  26%|████████████████████                                                          | 258/1000 [00:01<00:04, 166.00it/s]
# 333506968007 already exists in the database.
#  30%|███████████████████████▏                                                      | 297/1000 [00:01<00:03, 178.55it/s]
# 292322938301 already exists in the database.
# 283756919482 already exists in the database.
#  40%|██████████████████████████████▉                                               | 396/1000 [00:02<00:03, 163.44it/s]
# 392485249690 already exists in the database.
# 133310924492 already exists in the database.
# 392381554592 already exists in the database.
# 233477045103 already exists in the database.
#  50%|██████████████████████████████████████▋                                       | 496/1000 [00:02<00:03, 155.45it/s]
# 223838043911 already exists in the database.
# 192285797825 already exists in the database.
# 192285797818 already exists in the database.
#  54%|█████████████████████████████████████████▉                                    | 538/1000 [00:03<00:02, 177.27it/s]
# 192285797808 already exists in the database.
#  79%|█████████████████████████████████████████████████████████████▌                | 790/1000 [00:04<00:01, 177.68it/s]
# 352648427375 already exists in the database.
#  90%|█████████████████████████████████████████████████████████████████████▉        | 896/1000 [00:05<00:00, 154.89it/s]
# 114010719079 already exists in the database.
# 192832373115 already exists in the database.
# 303474693487 already exists in the database.
# 143338521826 already exists in the database.
# 113950277133 already exists in the database.
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:05<00:00, 167.45it/s]

# %% [markdown]
# ### Getting the SQL table into Python Dataframe

# %%
conn = pymysql.connect(host='localhost', user = 'root', password = password_sql, database=DB)

Query = pd.read_sql_query('''select itemid,sponsor_flag,sellerscore,itemprice,itemsold,bestoffer_flag,returnsallowed_flag,shippingprice,conditions
from eBay_items''', conn)

eBay_items_df = pd.DataFrame(Query, columns=['itemid','sponsor_flag','sellerscore','itemprice','itemsold','bestoffer_flag','returnsallowed_flag','shippingprice','conditions'])

conn.close()

eBay_items_df.head()
# Out:
#          itemid  sponsor_flag  sellerscore  itemprice  itemsold  \
# 0  111121377380             0         1739    84889.0       6.0
# 1  111320062974             0         1739    79889.0       2.0
# 2  111352455994             0         1739    82889.0       NaN
# 3  111378999421             0         1739    89899.0       NaN
# 4  111524384363             0         1739    99989.0       1.0
#
#    bestoffer_flag  returnsallowed_flag  shippingprice conditions
# 0               0                    1            NaN        New
# 1               0                    1            NaN        New
# 2               0                    1            NaN        New
# 3               0                    1            NaN        New
# 4               0                    1         2498.0        New

# %% [markdown]
# ### Getting min, max and mean for all numerical/binary variables grouped by sponsor_flag and conditions

# %%
conn = pymysql.connect(host='localhost', user = 'root', password = password_sql, database=DB)
query = pd.read_sql_query(
'''
SELECT
    conditions,
    sponsor_flag,
    AVG(sellerscore), MIN(sellerscore), MAX(sellerscore), STDDEV(sellerscore),
    AVG(itemprice), MIN(itemprice), MAX(itemprice), STDDEV(itemprice),
    AVG(itemsold), MIN(itemsold), MAX(itemsold), STDDEV(itemsold),
    AVG(bestoffer_flag), MIN(bestoffer_flag), MAX(bestoffer_flag), STDDEV(bestoffer_flag),
    AVG(returnsallowed_flag), MIN(returnsallowed_flag), MAX(returnsallowed_flag), STDDEV(returnsallowed_flag),
    AVG(shippingprice), MIN(shippingprice), MAX(shippingprice), STDDEV(shippingprice)
FROM
    eBay_items
GROUP BY conditions , sponsor_flag
order by conditions
''', conn)
eBay_items_summary = pd.DataFrame(query, columns=['conditions','sponsor_flag','AVG(sellerscore)','MIN(sellerscore)','MAX(sellerscore)','STDDEV(sellerscore)','AVG(itemprice)','MIN(itemprice)','MAX(itemprice)','STDDEV(itemprice)',  \
                                              'AVG(itemsold)','MIN(itemsold)','MAX(itemsold)','STDDEV(itemsold)', 'AVG(bestoffer_flag)','MIN(bestoffer_flag)','MAX(bestoffer_flag)','STDDEV(bestoffer_flag)',  \
                                              'AVG(returnsallowed_flag)','MIN(returnsallowed_flag)','MAX(returnsallowed_flag)','STDDEV(returnsallowed_flag)', 'AVG(shippingprice)','MIN(shippingprice)','MAX(shippingprice)','STDDEV(shippingprice)'])
conn.close()
eBay_items_summary
# Out:
#                  conditions  sponsor_flag  AVG(sellerscore)  MIN(sellerscore)  \
# 0  Manufacturer refurbished             0       135993.6863                 0
# 1  Manufacturer refurbished             1        83648.5733              1039
# 2                       New             0         6152.8860                 0
# 3                       New             1        94150.5000              1246
# 4                  Open box             0        38393.8068                 0
# 5                  Open box             1        46134.7500              2664
# 6        Seller refurbished             0       181072.5746                 3
# 7        Seller refurbished             1        62518.0000               839
# 8                      Used             0        18026.9978                 0
# 9                      Used             1        34081.7500                29
#
#    MAX(sellerscore)  STDDEV(sellerscore)  AVG(itemprice)  MIN(itemprice)  \
# 0           2265914        269137.673888      28647.7815            4500
# 1            434816         45750.261368      17929.7200            7998
# 2            115668         19258.517781      52117.5439           14999
# 3            187055         92904.500000      38999.5000           38999
# 4            213419         53899.942637      23176.5909            8995
# 5             84742         38760.115695      21748.0000           12105
# 6           2265907        465632.861040      23847.7222            6998
# 7            213416         76102.032360      14953.1613            8199
# 8            311763         48709.153251      16344.7978            3300
# 9            213416         51166.194590      11700.0625            3999
#
#    MAX(itemprice)  STDDEV(itemprice)  ...  MAX(bestoffer_flag)  \
# 0          107900       22373.459009  ...                    1
# 1           59999        7213.888722  ...                    0
# 2          189900       26127.820770  ...                    1
# 3           39000           0.500000  ...                    1
# 4           91597       14140.900734  ...                    1
# 5           34997        8292.015256  ...                    0
# 6           99999       20996.362322  ...                    1
# 7           24500        4453.032827  ...                    1
# 8          102900       12085.231646  ...                    1
# 9           38499        8192.874301  ...                    1
#
#    STDDEV(bestoffer_flag)  AVG(returnsallowed_flag)  MIN(returnsallowed_flag)  \
# 0                0.268849                    0.9281                         0
# 1                0.000000                    1.0000                         1
# 2                0.474415                    0.6228                         0
# 3                0.500000                    0.5000                         0
# 4                0.317369                    0.8523                         0
# 5                0.000000                    1.0000                         1
# 6                0.306518                    0.9337                         0
# 7                0.176685                    0.9677                         0
# 8                0.498937                    0.5258                         0
# 9                0.433013                    0.8750                         0
#
#    MAX(returnsallowed_flag)  STDDEV(returnsallowed_flag)  AVG(shippingprice)  \
# 0                         1                     0.258315             68.1209
# 1                         1                     0.000000              0.0000
# 2                         1                     0.484684            686.7111
# 3                         1                     0.500000            300.0000
# 4                         1                     0.354829             87.5965
# 5                         1                     0.000000              0.0000
# 6                         1                     0.248803            111.7227
# 7                         1                     0.176685              0.0000
# 8                         1                     0.499332            436.3574
# 9                         1                     0.330719            135.9091
#
#    MIN(shippingprice)  MAX(shippingprice)  STDDEV(shippingprice)
# 0                   0                4000             444.694236
# 1                   0                   0               0.000000
# 2                   0                2998             937.737623
# 3                 300                 300               0.000000
# 4                   0                1595             326.132513
# 5                   0                   0               0.000000
# 6                   0                2400             442.108411
# 7                   0                   0               0.000000
# 8                   0                4995             687.276965
# 9                   0                1000             307.754464
#
# [10 rows x 26 columns]

# %% [markdown]
# ### Findings

# %% [markdown]
# ### 1) On average, the seller scores are higher for non-sponsored  as compared to sponsored items for conditions such as Manufacture Refurbished and Seller refurbished
# ### On the other hand sponsored items have a higher average seller score for Open Box, New and Used condition items

# %% [markdown]
# ### 2) For all conditions, we see that on average the price of an item is higher for non-sponsored items as compared to sponsored items ones

# %% [markdown]
# ### 3)The average number of non-sponsored items sold is more than the average number of sponsored items sold for Manufacture Refurbished, Open Box and Used conditions
# ### The opposite is true for New and Seller Refurbished Items

# %% [markdown]
# ### 4) For all conditions, we see that the average shipping price is higher for non-sponsored items as compared to sponsored items

# %% [markdown]
# ### 5) For all conditions, apart from the New one, the proportion of items that have best offers is higher for non-sponsored than sponsored ones

# %% [markdown]
# ### 6) For all conditions, apart from the New one, the proportion of items  number of items that are allowed to be returned is higher for sponsored than non-sponsored ones

# %% [markdown]
# ### Based on the above findings we see:
# ### Generally higher the item price and shipping price associated with the item, higher the chance of the item being non-sponsored
# ### Generally, if the item has the best offer, there is a higher chance of the item being a non-sponsored one than a sponsored one
# ### Generally, if the item can be returned, there is a higher chance of the item being a sponsored one than a non-sponsored one
# ### Thus the metrics such as item price, shipping price, best offer flag and returns allowed flag can be used in statistical modelling to determine if the given item is sponsored or non-sponsored.
